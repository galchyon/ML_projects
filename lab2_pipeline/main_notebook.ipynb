# %% [markdown]
# ## Practice: Basic Artificial Neural Networks
# Credits: this notebook belongs to [Practical DL](https://docs.google.com/forms/d/e/1FAIpQLScvrVtuwrHSlxWqHnLt1V-_7h2eON_mlRR6MUb3xEe5x9LuoA/viewform?usp=sf_link) course by Yandex School of Data Analysis.
#
# We will start working with neural networks on the practice session. Your homework will be to finish the implementation of the layers.

# %% [markdown]
# Our goal is simple, yet an actual implementation may take some time :). We are going to write an Artificial Neural Network (almost) from scratch. The software design was heavily inspired by [PyTorch](http://pytorch.org) which is the main framework of our course

# %% [markdown]
# Speaking about the homework (once again, it will be really similar to this seminar), it requires sending **multiple** files, please do not forget to include all the files when sending to TA. The list of files:
# - This notebook
# - modules.ipynb with all blocks implemented (except maybe `Conv2d` and `MaxPool2d` layers implementation which are part of 'advanced' version of this homework)

# %%
# %matplotlib inline
from time import time, sleep
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

# %% [markdown]
# # Framework

# %% [markdown]
# Implement everything in `modules.ipynb`. Read all the comments thoughtfully to ease the pain. Please try not to change the prototypes.
#
# Do not forget, that each module should return **AND** store `output` and `gradInput`.
#
# The typical assumption is that `module.backward` is always executed after `module.forward`,
# so `output` is stored, this would be useful for `SoftMax`.

# %% [markdown]
# ### Tech note
# Prefer using `np.multiply`, `np.add`, `np.divide`, `np.subtract` instead of `*`,`+`,`/`,`-` for better memory handling.
#
# Example: suppose you allocated a variable
#
# ```
# a = np.zeros(...)
# ```
# So, instead of
# ```
# a = b + c  # will be reallocated, GC needed to free
# ```
# You can use:
# ```
# np.add(b,c,out = a) # puts result in `a`
# ```

# %%
# (re-)load layers
# %run modules_ready.ipynb

# %% [markdown]
# # Toy example

# %% [markdown]
# Use this example to debug your code, start with logistic regression and then test other layers. You do not need to change anything here. This code is provided for you to test the layers. Also it is easy to use this code in MNIST task.

# %%
# Generate some data
N = 500

X1 = np.random.randn(N,2) + np.array([2,2])
X2 = np.random.randn(N,2) + np.array([-2,-2])

Y = np.concatenate([np.ones(N),np.zeros(N)])[:,None]
Y = np.hstack([Y, 1-Y])

X = np.vstack([X1,X2])
plt.scatter(X[:,0],X[:,1], c = Y[:,0], edgecolors= 'none')

# %% [markdown]
# Define a **logistic regression** for debugging.

# %%
net = Sequential()
net.add(Linear(2, 2))
net.add(LogSoftMax())

criterion = ClassNLLCriterion()

print(net)

# Test something like that then 

net2 = Sequential()
net2.add(Linear(2, 4))
net2.add(ReLU())
net2.add(Linear(4, 8))
net2.add(ReLU())
net2.add(Linear(8, 4))
net2.add(ReLU())
net2.add(Linear(4, 2))
net2.add(LogSoftMax())
print(net2)
# Out:
# Linear 2 -> 2
# LogSoftMax
#
# Linear 2 -> 4
# ReLU
# Linear 4 -> 8
# ReLU
# Linear 8 -> 4
# ReLU
# Linear 4 -> 2
# LogSoftMax

# %% [markdown]
# Start with batch_size = 1000 to make sure every step lowers the loss, then try stochastic version.

# %%
# Iptimizer params
optimizer_config = {'learning_rate' : 1e-1, 'momentum': 0.9}
optimizer_state = {}

# Looping params
n_epoch = 20
batch_size = 128

# %%
# batch generator
def get_batches(dataset, batch_size):
    X, Y = dataset
    n_samples = X.shape[0]
        
    # Shuffle at the start of epoch
    indices = np.arange(n_samples)
    np.random.shuffle(indices)
    
    for start in range(0, n_samples, batch_size):
        end = min(start + batch_size, n_samples)
        
        batch_idx = indices[start:end]
    
        yield X[batch_idx], Y[batch_idx]

# %% [markdown]
# ### Train

# %% [markdown]
# Basic training loop. Examine it.

# %%
loss_history = []

for i in range(n_epoch):
    for x_batch, y_batch in get_batches((X, Y), batch_size):
        
        net.zeroGradParameters()
        
        # Forward
        predictions = net.forward(x_batch)
        loss = criterion.forward(predictions, y_batch)
    
        # Backward
        dp = criterion.backward(predictions, y_batch)
        net.backward(x_batch, dp)
        
        # Update weights
        sgd_momentum(net.getParameters(), 
                     net.getGradParameters(), 
                     optimizer_config,
                     optimizer_state)      
        
        loss_history.append(loss)

    # Visualize
    display.clear_output(wait=True)
    plt.figure(figsize=(8, 6))
        
    plt.title("Training loss")
    plt.xlabel("#iteration")
    plt.ylabel("loss")
    plt.plot(loss_history, 'b')
    plt.show()
    
    print('Current loss: %f' % loss)
# Out:
# Current loss: 0.006051

# %%
optimizer_config = {'learning_rate' : 1e-1, 'momentum': 0.9}
optimizer_state = {}

# Looping params
n_epoch = 20
batch_size = 128

loss_history = []

for i in range(n_epoch):
    for x_batch, y_batch in get_batches((X, Y), batch_size):
        
        net2.zeroGradParameters()
        
        # Forward
        predictions = net2.forward(x_batch)
        loss = criterion.forward(predictions, y_batch)
    
        # Backward
        dp = criterion.backward(predictions, y_batch)
        net2.backward(x_batch, dp)
        
        # Update weights
        sgd_momentum(net2.getParameters(), 
                     net2.getGradParameters(), 
                     optimizer_config,
                     optimizer_state)      
        
        loss_history.append(loss)

    # Visualize
    display.clear_output(wait=True)
    plt.figure(figsize=(8, 6))
        
    plt.title("Training loss")
    plt.xlabel("#iteration")
    plt.ylabel("loss")
    plt.plot(loss_history, 'b')
    plt.show()
    
    print('Current loss: %f' % loss)
# Out:
# Current loss: 0.041882

# %% [markdown]
# # Digit classification

# %% [markdown]
# We are using old good [MNIST](http://yann.lecun.com/exdb/mnist/) as our dataset.

# %%
import mnist
X_train, y_train, X_val, y_val, X_test, y_test = mnist.load_dataset()

# %% [markdown]
# One-hot encode the labels first.

# %%
X_train.shape, y_train.shape
# Out:
# ((50000, 28, 28), (50000,))

# %%
# Your code goes here. ################################################
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder()
y_train = np.array(enc.fit_transform(y_train.reshape(-1, 1)).todense()) 
y_val = np.array(enc.transform(y_val.reshape(-1, 1)).todense()) 
y_test = np.array(enc.transform(y_test.reshape(-1, 1)).todense()) 

image_size = 28**2
X_train = X_train.reshape(X_train.shape[0], image_size)
X_val = X_val.reshape(X_val.shape[0], image_size)
X_test = X_test.reshape(X_test.shape[0], image_size)

# %%
X_train.shape, y_train.shape
# Out:
# ((50000, 784), (50000, 10))

# %% [markdown]
# - **Compare** `ReLU`, `ELU`, `LeakyReLU`, `SoftPlus` activation functions.
# You would better pick the best optimizer params for each of them, but it is overkill for now. Use an architecture of your choice for the comparison.
# - **Try** inserting `BatchNormalization` (folowed by `ChannelwiseScaling`) between `Linear` module and activation functions.
# - Plot the losses both from activation functions comparison and `BatchNormalization` comparison on one plot. Please find a scale (log?) when the lines are distinguishable, do not forget about naming the axes, the plot should be goodlooking.
# - Plot the losses for two networks: one trained by momentum_sgd, another one trained by Adam. Which one performs better?
# - Hint: good logloss for MNIST should be around 0.5.

# %%
# Your code goes here. ################################################

def train(net, optimizer):
    history_loss = []
    for _ in range(n_epoch):
        for x_batch, y_batch in get_batches((X_train, y_train), batch_size):
            net.zeroGradParameters()
            predictions = net.forward(x_batch)
            loss = criterion.forward(predictions, y_batch)
            dp = criterion.backward(predictions, y_batch)
            net.backward(x_batch, dp)
            optimizer(net.getParameters(),
                        net.getGradParameters(),
                        optimizer_config,
                        optimizer_state)
            history_loss.append(loss) 
    return history_loss

# %% [markdown]
# ## ReLU

# %%
# %%time

batch_size = 128
output_size = 10
n_epoch = 2

net = Sequential()
net.add(Linear(image_size, 128))
net.add(ReLU())
net.add(Linear(128, output_size))
net.add(LogSoftMax())

criterion = ClassNLLCriterion()

print(net)
optimizer_config = {'learning_rate' : 0.1, 'momentum': 0.95}
optimizer_state = {}
loss_history_relu = train(net, sgd_momentum)
# Out:
# Linear 784 -> 128
# ReLU
# Linear 128 -> 10
# LogSoftMax
#
# CPU times: total: 2min 55s
# Wall time: 46 s

# %% [markdown]
# ## ELU

# %%
# %%time

batch_size = 128
output_size = 10
n_epoch = 2

net = Sequential()
net.add(Linear(image_size, 128))
net.add(ELU())
net.add(Linear(128, output_size))
net.add(LogSoftMax())

criterion = ClassNLLCriterion()

print(net)
optimizer_config = {'learning_rate' : 0.1, 'momentum': 0.95}
optimizer_state = {}
loss_history_elu = train(net, sgd_momentum)
# Out:
# Linear 784 -> 128
# ELU
# Linear 128 -> 10
# LogSoftMax
#
# CPU times: total: 3min 3s
# Wall time: 48.1 s

# %% [markdown]
# ## LeakyReLU

# %%
# %%time

batch_size = 128
output_size = 10
n_epoch = 2

net = Sequential()
net.add(Linear(image_size, 128))
net.add(LeakyReLU())
net.add(Linear(128, output_size))
net.add(LogSoftMax())

criterion = ClassNLLCriterion()

print(net)
optimizer_config = {'learning_rate' : 0.1, 'momentum': 0.95}
optimizer_state = {}
loss_history_relu_l = train(net, sgd_momentum)
# Out:
# Linear 784 -> 128
# LeakyReLU
# Linear 128 -> 10
# LogSoftMax
#
# CPU times: total: 3min 15s
# Wall time: 50.5 s

# %% [markdown]
# ## SoftPlus

# %%
# %%time

batch_size = 128
output_size = 10
n_epoch = 2

net = Sequential()
net.add(Linear(image_size, 128))
net.add(SoftPlus())
net.add(Linear(128, output_size))
net.add(LogSoftMax())

criterion = ClassNLLCriterion()

print(net)
optimizer_config = {'learning_rate' : 0.1, 'momentum': 0.95}
optimizer_state = {}
loss_history_soft_plus = train(net, sgd_momentum)
# Out:
# Linear 784 -> 128
# SoftPlus
# Linear 128 -> 10
# LogSoftMax
#
# CPU times: total: 2min 59s
# Wall time: 46 s

# %% [markdown]
# ## ReLU + BatchNormalization

# %%
# %%time
batch_size = 128
output_size = 10
n_epoch = 2

net = Sequential()
net.add(Linear(image_size, 128))
net.add(BatchNormalization())
net.add(ChannelwiseScaling(128))
net.add(ReLU())
net.add(Linear(128, output_size))
net.add(LogSoftMax())

criterion = ClassNLLCriterion()

print(net)

optimizer_config = {'learning_rate' : 0.1, 'momentum': 0.95}
optimizer_state = {}
loss_history_batchn_relu = train(net, sgd_momentum)
# Out:
# Linear 784 -> 128
# BatchNormalization
# ChannelwiseScaling
# ReLU
# Linear 128 -> 10
# LogSoftMax
#
# CPU times: total: 3min 12s
# Wall time: 51.8 s

# %% [markdown]
# ## ELU + BatchNorm

# %%
# %%time
batch_size = 128
output_size = 10
n_epoch = 2

net = Sequential()
net.add(Linear(image_size, 128))
net.add(BatchNormalization())
net.add(ChannelwiseScaling(128))
net.add(ELU())
net.add(Linear(128, output_size))
net.add(LogSoftMax())

criterion = ClassNLLCriterion()

print(net)

optimizer_config = {'learning_rate' : 0.1, 'momentum': 0.95}
optimizer_state = {}
loss_history_batchn_elu = train(net, sgd_momentum)
# Out:
# Linear 784 -> 128
# BatchNormalization
# ChannelwiseScaling
# ELU
# Linear 128 -> 10
# LogSoftMax
#
# CPU times: total: 3min 16s
# Wall time: 50.4 s

# %% [markdown]
# ## LeakyReLU + BatchNorm

# %%
# %%time
batch_size = 128
output_size = 10
n_epoch = 2

net = Sequential()
net.add(Linear(image_size, 128))
net.add(BatchNormalization())
net.add(ChannelwiseScaling(128))
net.add(LeakyReLU())
net.add(Linear(128, output_size))
net.add(LogSoftMax())

criterion = ClassNLLCriterion()

print(net)

optimizer_config = {'learning_rate' : 0.1, 'momentum': 0.95}
optimizer_state = {}
loss_history_batchn_l_Relu = train(net, sgd_momentum)
# Out:
# Linear 784 -> 128
# BatchNormalization
# ChannelwiseScaling
# LeakyReLU
# Linear 128 -> 10
# LogSoftMax
#
# CPU times: total: 3min 2s
# Wall time: 47.2 s

# %% [markdown]
# ## SoftPlus + BatchNorm

# %%
# %%time
batch_size = 128
output_size = 10
n_epoch = 2

net = Sequential()
net.add(Linear(image_size, 128))
net.add(BatchNormalization())
net.add(ChannelwiseScaling(128))
net.add(SoftPlus())
net.add(Linear(128, output_size))
net.add(LogSoftMax())

criterion = ClassNLLCriterion()

print(net)

optimizer_config = {'learning_rate' : 0.1, 'momentum': 0.95}
optimizer_state = {}
loss_history_batchn_softplus = train(net, sgd_momentum)
# Out:
# Linear 784 -> 128
# BatchNormalization
# ChannelwiseScaling
# SoftPlus
# Linear 128 -> 10
# LogSoftMax
#
# CPU times: total: 2min 54s
# Wall time: 44.5 s

# %%
plt.rcParams['axes.grid'] = True

fig, axs = plt.subplots(2, 2, figsize=(10,10))
axs[0, 0].semilogy(loss_history_batchn_softplus, label='BatchNorm')
axs[0, 0].semilogy(loss_history_soft_plus, label='Without')
axs[0, 0].set_title('Soft Plus')


axs[0, 1].semilogy(loss_history_batchn_relu)
axs[0, 1].semilogy(loss_history_relu)
axs[0, 1].set_title('ReLU')


axs[1, 0].semilogy(loss_history_batchn_l_Relu)
axs[1, 0].semilogy(loss_history_relu_l)
axs[1, 0].set_title('LeakyReLU')


axs[1, 1].semilogy(loss_history_batchn_elu)
axs[1, 1].semilogy(loss_history_elu)
axs[1, 1].set_title('ELU')




for ax in axs.flat:
    ax.set(xlabel='#iteration', ylabel='Training loss')
    
fig.legend();

# %% [markdown]
# Compare ReLU, ELU, LeakyReLU, SoftPlus activation functions. You would better pick the best optimizer params for each of them, but it is overkill for now. Use an architecture of your choice for the comparison.
#
# Try inserting BatchNormalization (folowed by ChannelwiseScaling) between Linear module and activation functions.
#
# Plot the losses both from activation functions comparison and BatchNormalization comparison on one plot. Please find a scale (log?) when the lines are distinguishable, do not forget about naming the axes, the plot should be goodlooking.
#
# 1. кажется, что лучший результат дали ReLU и ELU
#
# 2. Графики с BatchNorm и без него различаются несильно для всех функций активации, кроме SoftPlus.  Для выбранных в пункте один активаций особых изменений не наблюдается.

# %% [markdown]
# ## Adam Oprimizer

# %%
# %%time

batch_size = 128
output_size = 10
n_epoch = 2

net = Sequential()
net.add(Linear(image_size, 128))
net.add(ReLU())
net.add(Linear(128, output_size))
net.add(LogSoftMax())

criterion = ClassNLLCriterion()

print(net)
optimizer_config = {'learning_rate' : 0.1, 'beta1': 0.97, 'beta2': 0.98, 'epsilon': 1e-2}
optimizer_state = {}
loss_history_adam_relu = train(net, adam_optimizer)
# Out:
# Linear 784 -> 128
# ReLU
# Linear 128 -> 10
# LogSoftMax
#
# CPU times: total: 2min 41s
# Wall time: 40.3 s

# %%
plt.semilogy(loss_history_adam_relu, label='Adam')
plt.semilogy(loss_history_relu, label='SGD')
plt.xlabel('#iteration')
plt.ylabel('Training loss')
plt.legend();

# %% [markdown]
# Plot the losses for two networks: one trained by momentum_sgd, another one trained by Adam. Which one performs better?
# Hint: good logloss for MNIST should be around 0.5.
#
# SGD дало меньший лосс, но у Adam он колеблется с меньшей аплитудой.

# %%
loss_history_adam_relu[-1], loss_history_relu[-1]
# Out:
# (0.1322381405960375, 0.06897231109377713)

# %%
plt.semilogy(loss_history_soft_plus, label='Soft Plus')

# %% [markdown]
# Write your personal opinion on the activation functions, think about computation times too. Does `BatchNormalization` help?

# %% [markdown]
# RelU и ELU отработали примерно одинаковое время, меньшее, чем LeakyReLU и SoftPlus (у них тоже примерно одинаковое).
# С добавлением BatchNorm у ReLU и ELU затраченное время выросло: ReLU с  44.9 s до 54.2 s, ELU с 44.8 s до 55.8 s, у LeakyReLU с SoftPlus наоборот сократилось: LeakyReLU 54.5 s до 52.3 s, SoftPlus 54.7 s до 51.1 s. Получается, для данной модели и данной задачи применение BN улучшило результаты SoftPlus - уменьшился лосс и время выполнения.

# %% [markdown]
# **Finally**, use all your knowledge to build a super cool model on this dataset. Use **dropout** to prevent overfitting, play with **learning rate decay**. You can use **data augmentation** such as rotations, translations to boost your score. Use your knowledge and imagination to train a model. Don't forget to call `training()` and `evaluate()` methods to set desired behaviour of `BatchNormalization` and `Dropout` layers.

# %%
batch_size = 128
output_size = 10
n_epoch = 5

net = Sequential()
net.add(Linear(image_size, 256))
net.add(BatchNormalization())
net.add(ReLU())
net.add(Dropout(0.3))
net.add(Linear(256, 128))
net.add(ReLU())
net.add(Linear(128, output_size))
net.add(LogSoftMax())


criterion = ClassNLLCriterion()

print(net)
optimizer_config = {'learning_rate' : 0.1, 'beta1': 0.97, 'beta2': 0.98, 'epsilon': 1e-2}
optimizer_state = {}
loss_history_adam_relu = train(net, adam_optimizer)
# Out:
# Linear 784 -> 256
# BatchNormalization
# ReLU
# Dropout
# Linear 256 -> 128
# ReLU
# Linear 128 -> 10
# LogSoftMax

# %%
def get_acc(X, Y):
    acc = 0
    count=0
    for x_batch, y_batch in get_batches((X, Y), batch_size):
        count+=1
        outs = net.forward(x_batch)
        acc1 = sum(outs.argmax(axis = 1)==y_batch.argmax(axis = 1))/batch_size
        #print(y_batch, y_batch.argmax(axis = 1))
        #print(acc1)
        #print(y_batch.argmax(axis = 1))
        acc += acc1

    return acc/count

# %% [markdown]
# Print here your accuracy on test set. It should be around 90%.

# %%
get_acc(X_val, y_val)
# Out:
# 0.9364121835443038

# %% [markdown]
# ### Comparing with PyTorch implementation
# The last (and maybe the easiest step after compared to the previous tasks: build a network with the same architecture as above now with PyTorch.
#
# You can refer to the `week0_09` or `Lab3_part2` notebooks for hints.
#
# __Good Luck!__

# %%
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in c:\programdata\anaconda3\lib\site-packages (1.5.1)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -nyio (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -upyterlab (c:\programdata\anaconda3\lib\site-packages)

# %%
import torch
import torch.nn as nn
import torchsummary

# %%
class SimpleNet(nn.Module):
    def __init__(self, input_shape=image_size, num_classes=10, input_channels=1):
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
             # This layer converts image into a vector to use Linear layers afterwards,
            nn.Linear(input_shape, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, num_classes),
            nn.LogSoftmax(dim=1)

            )

    def forward(self, inp):
        out = self.model(inp)

        return out

# %%
torchsummary.summary(SimpleNet(), (image_size,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 256]         200,960
#        BatchNorm1d-2                  [-1, 256]             512
#               ReLU-3                  [-1, 256]               0
#            Dropout-4                  [-1, 256]               0
#             Linear-5                  [-1, 128]          32,896
#               ReLU-6                  [-1, 128]               0
#             Linear-7                   [-1, 10]           1,290
#         LogSoftmax-8                   [-1, 10]               0
# ================================================================
# Total params: 235,658
# Trainable params: 235,658
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.90
# Estimated Total Size (MB): 0.91
# ----------------------------------------------------------------

# %%
def train_torch(model, loss_func, opt, n_epochs: int):
    history_loss = []
    model.train(True)
    for _ in range(n_epoch):
        for x_batch, y_batch in get_batches((X_train, y_train), batch_size):
            x_batch = torch.tensor(x_batch)
            y_batch = torch.tensor(y_batch)
            
            predictions = model.forward(x_batch)
            loss = loss_func(predictions, y_batch)
            opt.zero_grad()
            loss.backward()
            opt.step()
            history_loss.append(loss) 
    return history_loss

# %%
model = SimpleNet()
opt = torch.optim.Adam(model.parameters(), lr=0.1)
loss_func = nn.CrossEntropyLoss()
n_epochs = 5
train_torch(model, loss_func, opt, n_epochs)
# Out:
# [tensor(2.3189, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor
dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4359, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2913, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4856, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3671, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5577, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4750, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3401, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5230, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2670, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4600, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3787, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3821, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3352, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4180, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2844, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3465, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3416, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5057, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4814, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6602, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4115, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3038, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3631, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6778, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4408, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3741, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.7996, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4451, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3432, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3818, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3027, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4938, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4382, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2802, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6976, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2802, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5279, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5957, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4006, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4084, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4353, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2973, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3425, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4651, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3958, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4674, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4452, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5552, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4987, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6346, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4005, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3494, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4211, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4127, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2974, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4315, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2693, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4649, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3527, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5593, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3467, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3173, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4009, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2670, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.7530, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5539, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3761, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3129, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4738, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4665, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5670, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4051, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3495, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3385, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5397, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5092, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4967, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2864, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4164, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3674, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5352, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3170, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4982, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2529, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4705, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4840, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2369, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.1992, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3680, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2829, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3126, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2843, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4680, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3892, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3814, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2325, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5332, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2742, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2418, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4873, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4209, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2118, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2503, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3101, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2157, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2289, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.1212, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4682, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3965, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2615, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4977, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4090, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2195, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2653, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.1357, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3161, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6892, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6338, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4626, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2904, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3725, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4209, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5562, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4398, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2325, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5763, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4940, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2257, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4070, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4565, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4222, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6034, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5091, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5699, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3655, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3679, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2978, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3410, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4967, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3580, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6224, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3651, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3151, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3932, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5413, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6054, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3919, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2451, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4871, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2191, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2704, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4733, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3505, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.1697, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3066, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2965, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3669, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.1353, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2958, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2766, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4539, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4023, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4506, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3459, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3387, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2714, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2781, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2020, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4448, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4312, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4380, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4443, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3943, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3375, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6119, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4348, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4199, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3614, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3265, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4826, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2793, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2550, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4398, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2597, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3252, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2909, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2511, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4114, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3822, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3524, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.7325, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3763, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3942, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2801, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6060, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3902, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5905, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5684, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4861, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3631, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4173, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4805, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.7118, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4088, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3843, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2194, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3245, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4596, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4056, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3280, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3664, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4811, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4297, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2425, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2166, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4421, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3856, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.1797, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3861, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2913, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2876, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3370, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.1967, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2623, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6610, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4824, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3441, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5217, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5055, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4372, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.2967, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3782, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6786, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.7582, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6517, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3369, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5618, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5430, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4936, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4666, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4555, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4887, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3437, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4854, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3298, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4288, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3227, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4184, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4420, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4085, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3362, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4010, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4587, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.6256, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4938, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5076, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.1922, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3884, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3882, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.4146, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.3995, dtype=torch.float64, grad_fn=<DivBackward1>),
#  tensor(0.5834, dtype=torch.float64, grad_fn=<DivBackward1>),
#  ...]

# %%
def get_acc_torch(model, X, Y):
    acc = 0
    count=0
    for x_batch, y_batch in get_batches((X, Y), batch_size):
        count+=1
        x_batch = torch.tensor(x_batch)
        y_batch = torch.tensor(y_batch)
        outs = model.forward(x_batch)
        #print(torch.argmax(outs, 1), torch.argmax(y_batch, 1))
        acc1 = (torch.argmax(outs, 1) == torch.argmax(y_batch, 1)).sum()/batch_size
        #print((torch.argmax(outs, 1) == torch.argmax(y_batch, 1)))
        #acc1 = sum(outs.argmax(axis = 1)==y_batch.argmax(axis = 1))/batch_size
        #print(y_batch, y_batch.argmax(axis = 1))
        #print(acc1)
        #print(y_batch.argmax(axis = 1))
        acc += acc1.item()

    return acc/count

# %%
get_acc_torch(model, X_val, y_val)
# Out:
# 0.9598496835443038

# %% [markdown]
# точность классификации повысилась
